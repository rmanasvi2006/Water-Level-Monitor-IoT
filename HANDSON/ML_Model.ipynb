# %%
#install required libraries

# %pip install -q numpy pandas matplotlib seaborn scikit-learn tensorflow
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import tensorflow as tf

# %%
DATA_PATH = "water_dissegration_data.csv"
print("Data File Exists: ", Path(DATA_PATH).exists())
training_data = pd.read_csv(DATA_PATH)
print("First 5 rows", training_data.head())
print("Value Counts:",training_data.label.value_counts())
training_data.info()
# Out:
# Data File Exists:  True
# First 5 rows                    Timestamp   distance      diff  slope        label
# 0  2024-06-08 09:00:00+05:30  86.134198  0.000000    0.0  no_activity
# 1  2024-06-08 09:00:10+05:30  86.098701 -0.035497    0.0  no_activity
# 2  2024-06-08 09:00:20+05:30  86.073425 -0.025276    0.0  no_activity
# 3  2024-06-08 09:00:30+05:30  86.060569 -0.012856    0.0  no_activity
# 4  2024-06-08 09:00:40+05:30  86.052529 -0.008040    0.0  no_activity
# Value Counts: label
# no_activity        23434
# filling            13138
# flush               2056
# washing_machine     1985
# geyser              1415
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42028 entries, 0 to 42027
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  42028 non-null  object
#  1   distance   42028 non-null  float64
#  2   diff       42028 non-null  float64
# ...
